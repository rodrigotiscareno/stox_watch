05:00:00-05:00           NaN           NaN          NaN
# 2023-10-25 06:00:00-04:00           NaN           NaN          NaN
# 2023-08-03 17:00:00-04:00          1.19           NaN          NaN
# 2023-08-03 16:00:00-04:00          1.19           NaN          NaN
# 2023-05-04 12:00:00-04:00          1.43          1.52       0.0603
# 2023-02-02 11:00:00-05:00          1.94          1.88      -0.0288
# 2022-10-27 12:00:00-04:00          1.27          1.29       0.0155
# 2022-07-28 12:00:00-04:00          1.16          1.20       0.0325
# 2022-04-28 12:00:00-04:00          1.43          1.52       0.0644
# 2022-01-27 11:00:00-05:00          1.89          2.10       0.1117

# %%
pd.DataFrame(apple.news)
# Out:
#                                    uuid  \
# 0  986618e4-1b71-3a75-9f76-0c27165a64d7
# 1  991e41dc-06ef-448b-8f40-3616f33f737c
# 2  7b329c2e-e805-3c4e-a777-4aaed9204c37
# 3  d0b327d0-566e-35ea-8461-d0801a449dae
# 4  1c7f032f-4280-3312-bbce-eb8672ed2727
# 5  f5831b1c-b185-37be-b9cc-7fdde1959e14
# 6  aacb2a6c-60ff-39ea-869e-641de2005432
# 7  6c4935e0-c829-3395-b169-9039577b9bb4
#
#                                                title             publisher  \
# 0  Apple Wants to Crash ChatGPT's Party -- Here's...         TheStreet.com
# 1  The stock market is overbought and due for a c...         Yahoo Finance
# 2  Tech Employee Stock Benefits Could Bite Back a...          Investopedia
# 3  The "Magnificent Seven" Stocks Are Soaring Tow...           Motley Fool
# 4  3 Things About Microsoft Stock That Smart Inve...           Motley Fool
# 5  Got $1,000? 5 Buffett Stocks to Buy and Hold F...           Motley Fool
# ...

# %%
from yahooquery import Ticker

aapl = Ticker('aapl')
tickers = Ticker(['tsla', 'u'])

# %%
aapl.balance_sheet(frequency="q")
# Out:
#          asOfDate periodType currencyCode  AccountsPayable  \
# symbol
# aapl   2022-06-30         3M          USD     4.834300e+10
# aapl   2022-09-30         3M          USD     6.411500e+10
# aapl   2022-12-31         3M          USD     5.791800e+10
# aapl   2023-03-31         3M          USD     4.294500e+10
#
#         AccountsReceivable  AccumulatedDepreciation  \
# symbol
# aapl          2.180300e+10            -7.151600e+10
# aapl          2.818400e+10            -7.234000e+10
# aapl          2.375200e+10            -6.804400e+10
# aapl          1.793600e+10            -6.966800e+10
#
#         AvailableForSaleSecurities  CapitalStock  CashAndCashEquivalents  \
# symbol
# aapl                  1.310770e+11  6.211500e+10            2.750200e+10
# aapl                  1.208050e+11  6.484900e+10            2.364600e+10
# aapl                           NaN  6.639900e+10            2.053500e+10
# aapl                  1.104610e+11  6.956800e+10            2.468700e+10
#
# ...

# %%
aapl.cash_flow()
# Out:
#          asOfDate periodType currencyCode  BeginningCashPosition  \
# symbol
# aapl   2019-09-30        12M          USD           2.591300e+10
# aapl   2020-09-30        12M          USD           5.022400e+10
# aapl   2021-09-30        12M          USD           3.978900e+10
# aapl   2022-09-30        12M          USD           3.592900e+10
# aapl   2022-12-31        TTM          USD           3.863000e+10
# aapl   2023-03-31        TTM          USD           2.918000e+10
#
#         CapitalExpenditure  CashDividendsPaid  \
# symbol
# aapl         -1.049500e+10      -1.411900e+10
# aapl         -7.309000e+09      -1.408100e+10
# aapl         -1.108500e+10      -1.446700e+10
# aapl         -1.070800e+10      -1.484100e+10
# aapl         -1.169200e+10      -1.487700e+10
# aapl         -1.209400e+10      -1.493200e+10
#
#         CashFlowFromContinuingFinancingActivities  \
# symbol
# aapl                                -9.097600e+10
# ...

# %%
aapl.income_statement()
# Out:
#          asOfDate periodType currencyCode  BasicAverageShares  BasicEPS  \
# symbol
# aapl   2019-09-30        12M          USD        1.847134e+10    2.9925
# aapl   2020-09-30        12M          USD        1.735212e+10    3.3100
# aapl   2021-09-30        12M          USD        1.670127e+10    5.6700
# aapl   2022-09-30        12M          USD        1.621596e+10    6.1500
# aapl   2022-12-31        TTM          USD                 NaN       NaN
# aapl   2023-03-31        TTM          USD                 NaN       NaN
#
#         CostOfRevenue  DilutedAverageShares  DilutedEPS  \
# symbol
# aapl     1.617820e+11          1.859565e+10      2.9725
# aapl     1.695590e+11          1.752821e+10      3.2800
# aapl     2.129810e+11          1.686492e+10      5.6100
# aapl     2.235460e+11          1.632582e+10      6.1100
# aapl     2.206660e+11                   NaN         NaN
# aapl     2.188070e+11                   NaN         NaN
#
# ...
